# %% [markdown]
# This program creates a linear regression model from scratch to make a prediciction of a cars MPG given a description of the car.

# %%
# !pip install huggingface_hub
# !pip install datasets
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from datasets import load_dataset
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 28.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 21.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 15.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 70.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 14.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 31.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 16.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Importing of Data

# %%
uurl = "https://huggingface.co/datasets/arjund1999/AutoMPG/raw/main/auto-mpg.data"
data = pd.read_table(url, header=None, sep=r'\t')
# Out:
# <ipython-input-43-a665f651240a>:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data = pd.read_table(url, header=None, sep=r'\t')

# %% [markdown]
# # Cleaning of Data

# %%
df = pd.DataFrame(data)  # Creating a data frame w/ headers
print(df)
# Out:
#     18.0   8   307.0      130.0      3504.      12.0   70  1  \
# 0    15.0   8   350.0      165.0      3693.      11...
# 1    18.0   8   318.0      150.0      3436.      11...
# 2    16.0   8   304.0      150.0      3433.      12...
# 3    17.0   8   302.0      140.0      3449.      10...
# 4    15.0   8   429.0      198.0      4341.      10...
# ..                                                 ...
# 392  27.0   4   140.0      86.00      2790.      15...
# 393  44.0   4   97.00      52.00      2130.      24...
# 394  32.0   4   135.0      84.00      2295.      11...
# 395  28.0   4   120.0      79.00      2625.      18...
# 396  31.0   4   119.0      82.00      2720.      19...
#
#     chevrolet chevelle malibu
# 0           buick skylark 320
# 1          plymouth satellite
# 2               amc rebel sst
# 3                 ford torino
# 4            ford galaxie 500
# ..                        ...
# 392           ford mustang gl
# 393                 vw pickup
# ...

# %% [markdown]
# # Error Function (MSE)

# %%
def ssr_gradient(x, y, w):
    res = w[0] + w[1] * x - y
    return res.mean(), (res * x).mean()  # .mean() is a method of np.ndarray

# %% [markdown]
# # SGD Function
#
# Need to edit to make it work with dataframes

# %%
def gradient_descent(
     gradient, x, y, start, learn_rate=0.1, n_iter=50, tolerance=1e-06
 ):
  vector = start
  for _ in range(n_iter):
    diff = -learn_rate * np.array(gradient(x, y, vector))
    if np.all(np.abs(diff) <= tolerance):
      break
    vector += diff
  return vector

# %% [markdown]
# # Main

# %%
gradient_descent(
    ssr_gradient, x, y, start=[0.5, 0.5], learn_rate=0.0008,
    n_iter=100000
)
